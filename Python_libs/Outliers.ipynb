# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cgpa                  1000 non-null   float64
#  1   placement_exam_marks  1000 non-null   float64
#  2   placed                1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961240             32.225000     0.489000
# std       0.615898             19.130822     0.500129
# min       4.890000              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       9.120000            100.000000     1.000000

# %%
6.96+3*0.616
# Out:
# 8.808

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
#plt.subplot(1,2,1)
sns.distplot(df['cgpa'], hist=False)
# Out:
# /tmp/ipython-input-511938299.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'], hist=False)
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
32.225000+3*19.13
# Out:
# 89.61500000000001

# %%
sns.distplot(df['placement_exam_marks'])
# Out:
# /tmp/ipython-input-2541405458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# <Axes: xlabel='placement_exam_marks', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
sns.distplot(df['cgpa'])
plt.subplot(1,2,1)
sns.distplot(df['placement_exam_marks'])
# Out:
# /tmp/ipython-input-547852797.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# /tmp/ipython-input-547852797.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# <Axes: xlabel='placement_exam_marks', ylabel='Density'>

# %%
print(f"Mean value of our CGPA {df['cgpa'].mean()}")
print(f"Standard deviation value of our CGPA {df['cgpa'].std()}")
print(f"Min value of our CGPA {df['cgpa'].min()}")
print(f"Max value of our CGPA {df['cgpa'].max()}")
# Out:
# Mean value of our CGPA 6.96124
# Standard deviation value of our CGPA 0.6158978751323894
# Min value of our CGPA 4.89
# Max value of our CGPA 9.12

# %%
# Finding the boundary Values

print("Highest Allowed", df['cgpa'].mean()+3*df['cgpa'].std())
print("Lowest Allowed", df['cgpa'].mean()-3*df['cgpa'].std())
# Out:
# Highest Allowed 8.808933625397168
# Lowest Allowed 5.113546374602832

# %%
upper_limit = df['cgpa'].mean()+3*df['cgpa'].std()
lower_limit = df['cgpa'].mean()-3*df['cgpa'].std()

# %%
# Finding the Outlier

df[(df['cgpa']> upper_limit) | (df['cgpa']<lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
# Trimming the Outliers

new_df = df[(df['cgpa']<=8.8) & (df['cgpa']>= 5.1135)]

# %%
new_df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 0 to 998
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cgpa                  995 non-null    float64
#  1   placement_exam_marks  995 non-null    float64
#  2   placed                995 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 31.1 KB

# %%
# H.W is please CAP your data wrt OUTLIER
df1_cap = df.copy()

df1_cap['cgpa']=np.where(
                          df1_cap['cgpa']>upper_limit, upper_limit,
                          np.where(df1_cap['cgpa']<lower_limit, lower_limit,
                                  df1_cap['cgpa'] )
                        )

# %%
df1_cap
# Out:
#          cgpa  placement_exam_marks  placed
# 0    7.190000                  26.0       1
# 1    7.460000                  38.0       1
# 2    7.540000                  40.0       1
# 3    6.420000                   8.0       1
# 4    7.230000                  17.0       0
# ..        ...                   ...     ...
# 995  8.808934                  44.0       1
# 996  8.808934                  65.0       1
# 997  5.113546                  34.0       0
# 998  8.620000                  46.0       1
# 999  5.113546                  10.0       1
#
# [1000 rows x 3 columns]

# %%
# Finding Outlier via Z-score
# Approach 2

df['cgpa_z_score'] = (df['cgpa']-df['cgpa'].mean())/df['cgpa'].std()

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_z_score
# 0  7.19                  26.0       1      0.371425
# 1  7.46                  38.0       1      0.809810
# 2  7.54                  40.0       1      0.939701
# 3  6.42                   8.0       1     -0.878782
# 4  7.23                  17.0       0      0.436371

# %%
df['cgpa_z_score'].unique()
# Out:
# array([ 3.71425214e-01,  8.09809581e-01,  9.39701245e-01, -8.78782054e-01,
#         4.36371046e-01,  5.50026252e-01, -4.40397688e-01,  2.57770008e-01,
#        -8.30072680e-01,  1.28066686e+00, -2.29323733e-01, -9.43727887e-01,
#        -6.18998726e-01, -2.08027995e+00,  1.54045019e+00,  2.25297092e-01,
#        -7.00181016e-01,  9.72174161e-01, -5.07226949e-02,  1.08582937e+00,
#         7.61100207e-01, -3.26742481e-01, -1.47953100e+00, -8.46309138e-01,
#        -1.10609247e+00,  7.93573123e-01, -7.32653932e-01,  1.13453874e+00,
#        -1.70684141e+00, -1.18727476e+00,  1.93012518e+00,  8.42282497e-01,
#        -1.80614359e-01,  2.51463767e+00,  4.68843962e-01, -5.86525810e-01,
#        -4.24161230e-01,  1.44303144e+00,  1.49174082e+00, -6.69591529e-02,
#        -1.08985601e+00,  2.06001685e+00, -1.23598413e+00, -1.17103830e+00,
#         9.23464787e-01,  2.36850955e+00,  1.88141581e+00,  1.24819395e+00,
# ...

# %%
df[df['cgpa_z_score']>3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_z_score
# 995  8.87                  44.0       1      3.099150
# 996  9.12                  65.0       1      3.505062

# %%
df[df['cgpa_z_score']<-3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_z_score
# 485  4.92                  44.0       1     -3.314251
# 997  4.89                  34.0       0     -3.362960
# 999  4.90                  10.0       1     -3.346724

# %%
df[(df['cgpa_z_score']>3) | (df['cgpa_z_score']<-3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_z_score
# 485  4.92                  44.0       1     -3.314251
# 995  8.87                  44.0       1      3.099150
# 996  9.12                  65.0       1      3.505062
# 997  4.89                  34.0       0     -3.362960
# 999  4.90                  10.0       1     -3.346724

# %%
# HW .Please use Capping method for Approach 02

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(df['cgpa'])
# Out:
# <Axes: ylabel='cgpa'>

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
# Finding the IQR

Q3 = df['placement_exam_marks'].quantile(0.75)
Q1 = df['placement_exam_marks'].quantile(0.25)

# %%
Q1,Q3
# Out:
# (np.float64(17.0), np.float64(44.0))

# %%
IQR = Q3-Q1

# %%
IQR
# Out:
# np.float64(27.0)

# %%
upper_limit = Q3+(1.5*IQR)
lower_limit = Q1-(1.5*IQR)

# %%
upper_limit, lower_limit
# Out:
# (np.float64(84.5), np.float64(-23.5))

# %%
# Finding the Outliers

df[(df['placement_exam_marks']>upper_limit) | (df['placement_exam_marks']<lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_z_score
# 9    7.75                  94.0       1      1.280667
# 40   6.60                  86.0       1     -0.586526
# 61   7.51                  86.0       0      0.890992
# 134  6.33                  93.0       0     -1.024910
# 162  7.80                  90.0       0      1.361849
# 283  7.09                  87.0       0      0.209061
# 290  8.38                  87.0       0      2.303564
# 311  6.97                  87.0       1      0.014223
# 324  6.64                  90.0       0     -0.521580
# 630  6.56                  96.0       1     -0.651472
# 685  6.05                  87.0       1     -1.479531
# 730  6.14                  90.0       1     -1.333403
# 771  7.31                  86.0       1      0.566263
# 846  6.99                  97.0       0      0.046696
# 917  5.95                 100.0       0     -1.641896

# %%
# Trimming

new_df = df[df['placement_exam_marks']<80]

# %%
# Comparing

plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'])
# Out:
# /tmp/ipython-input-961280031.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# /tmp/ipython-input-961280031.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['placement_exam_marks'])
# ...
